# %%
import os
import shutil

from sklearn.model_selection import train_test_split
from glob import glob

# %%
img_list = glob('./dataset/images/*.png')
print(len(img_list))
# Out:
# 350

# %%
train_img_list, val_img_list = train_test_split(img_list,test_size=0.2, random_state= 2000)
print(len(train_img_list), len(val_img_list))
# Out:
# 280 70

# %%
label_list = glob('./dataset/labels/*.txt')
print(len(label_list))
print(label_list[0])
# Out:
# 350
# ./dataset/labels/00046754.txt

# %%
for list in label_list:
    with open(list, 'r') as f:
        datas = f.readlines()

    with open(list, 'w') as f:
        for data in datas:
            l = data.replace('-1 -1', '0')
            f.write(l)

# %%
with open('./train.txt', 'w') as f:
	f.write('\n'.join(train_img_list) + '\n')

with open('./val.txt', 'w') as f:
	f.write('\n'.join(val_img_list) + '\n')

# %%
# %cd ..
# Out:
# /home/uit-na/Desktop/yolo_study

# %%
import yaml

with open('./dataset/data.yaml', 'r') as f:
    data = yaml.load(f, Loader=yaml.FullLoader)

print(data)

data['train'] = '../train.txt'
data['val'] = '../val.txt'

with open('./dataset/data.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# {'names': ['cutlessfish'], 'nc': 1, 'train': '../train.txt', 'val': '../val.txt'}
# {'names': ['cutlessfish'], 'nc': 1, 'train': '../train.txt', 'val': '../val.txt'}

# %%
# %cd yolov7
# Out:
# /home/uit-na/Desktop/yolo_study/yolov7

# %%
# !python train.py --workers 8 --device 0 --data ../dataset/data.yaml --img 416 --cfg cfg/training/yolov7.yaml --weights '' --name cutlessfish_test1 --hyp data/hyp.scratch.p5.yaml
# Out:
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.12.1 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019.5625MB)
#
# Namespace(weights='', cfg='cfg/training/yolov7.yaml', data='../dataset/data.yaml', hyp='data/hyp.scratch.p5.yaml', epochs=300, batch_size=16, img_size=[416, 416], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='cutlessfish_test1', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/cutlessfish_test112', total_batch_size=16)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
